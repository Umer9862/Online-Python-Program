# %%
#we can use the \n command to write the text in poem form
print("Twinkle,twinkle,litlle star \n       How i wonder what you are! \n              Up above the workd so high \n              Like a diamond in the sky \nTwinkle,twinkle,litlle star \n       How i wonder what you are! \n")
# Out:
# Twinkle,twinkle,litlle star
#        How i wonder what you are!
#               Up above the workd so high
#               Like a diamond in the sky
# Twinkle,twinkle,litlle star
#        How i wonder what you are!

# %%
#we can use the python version command to print he current version
# !python -V
# Out:
# Python 3.9.7

# %% [markdown]
# # from datetime import datetime
#
# # datetime object containing current date and time
# now = datetime.now()
#
# print("now =", now)
# # dd/mm/YY H:M:S
# dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
# print("date and time =", dt_string)

# %%
PI = 3.14
r = float(input("Enter the radius of a circle:"))
area = PI * r * r
print("Area of a circle = %.2f" %area)
# Out:
# Enter the radius of a circle:12
# Area of a circle = 452.16

# %%
#we can take user name and reverse it by first making var with input and then printing in the reverse order
firstname = input("Please enter your first name");
lastname = input("Please enter your last name");
print(lastname +" "+ firstname)
# Out:
# Please enter your first nameg
# Please enter your last namem
# m g

# %%
#We can add the user input by taking input from the user and adding it in the print section
num1=int(input("please give us your number "))
num2=int(input("please give us your number "))
print(num1+num2)
# Out:
# please give us your number 1
# please give us your number 2
# 3
